# %% [markdown]
# # Hello Notebook
#
# A tiny sample for **ipynb**.
#
# ## Features
#
# - Markdown with $E = mc^2$
# - Code cells with syntax highlighting
# - Stream / result / error outputs

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ### Math
#
# Display math:
#
# $$
# \int_0^1 x^2 \, dx = \frac{1}{3}
# $$

# %%
answer = 6 * 7
answer
# Out:
# 42

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Conclusion
#
# Done.
